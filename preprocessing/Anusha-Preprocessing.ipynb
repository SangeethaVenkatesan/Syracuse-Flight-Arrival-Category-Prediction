# %%
# Generic inputs for most ML tasks
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn import tree
import graphviz
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from datetime import datetime
from sklearn.preprocessing import *
from sklearn.metrics import *
#pd.options.display.float_format = '{:,.2f}'.format

# setup interactive notebook mode
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML

# %%
dataset = pd.read_csv('../data_source/train_data/final_training_data.csv', parse_dates = ['Date (MM/DD/YYYY)'])
dataset.head()
# Out:
#   Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number Origin Airport  \
# 0           UA        2022-01-01           1282      N4901U            IAD
# 1           UA        2023-01-01            604      N814UA            DEN
# 2           UA        2023-01-01           2488      N38458            EWR
# 3           UA        2023-01-01           2645      N23721            ORD
# 4           UA        2022-01-02           1282      N4901U            IAD
#
#   Scheduled Arrival Time Actual Arrival Time  \
# 0                  23:10                0:01
# 1                  14:58               14:52
# 2                  23:14               23:15
# 3                  23:57               23:47
# 4                  23:10               23:27
#
#    Scheduled Elapsed Time (Minutes)  Actual Elapsed Time (Minutes)  \
# 0                                70                             76
# 1                               193                            177
# 2                                75                             62
# 3                               107                            100
# 4                                70                             64
#
#    Arrival Delay (Minutes)  ... Average Temperature(Celcius) /Day  \
# 0                       51  ...                              14.4
# 1                       -6  ...                              -0.9
# 2                        1  ...                              11.3
# 3                      -10  ...                               4.3
# 4                       17  ...                              14.7
#
#    Minimum Temperature(Celcius) /Day  Maximum Temperature(Celcius) /Day  \
# 0                               13.3                               16.7
# 1                               -4.9                                1.1
# 2                                7.2                               14.4
# 3                                2.8                                7.2
# 4                                5.6                               17.8
#
#    Daily Precipitation(mm) /Day  Maximum Snowfall(mm) /Day  \
# 0                          16.5                        0.0
# 1                           1.3                      100.0
# 2                           0.0                        0.0
# 3                           4.1                        0.0
# 4                           1.8                        0.0
#
#    Wind Direction(Degrees) /Day  Wind Speed(km/h) /Day  \
# 0                         165.0                    7.6
# 1                         111.0                   10.4
# 2                         241.0                   13.0
# 3                         245.0                    6.1
# 4                         324.0                   13.0
#
#   Peak Wind Gust(km/h) /Day  Atmospheric Pressure(hPa) /Day  \
# 0                       NaN                          1006.7
# 1                       NaN                          1010.5
# 2                       NaN                          1012.6
# 3                       NaN                          1013.7
# 4                       NaN                          1006.6
#
#    Sunshine Duration(m) /Day
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 28 columns]

# %%
dataset.columns
# Out:
# Index(['Carrier Code', 'Date (MM/DD/YYYY)', 'Flight Number', 'Tail Number',
#        'Origin Airport', 'Scheduled Arrival Time', 'Actual Arrival Time',
#        'Scheduled Elapsed Time (Minutes)', 'Actual Elapsed Time (Minutes)',
#        'Arrival Delay (Minutes)', 'Wheels-on Time', 'Taxi-In time (Minutes)',
#        'Delay Carrier (Minutes)', 'Delay Weather (Minutes)',
#        'Delay National Aviation System (Minutes)', 'Delay Security (Minutes)',
#        'Delay Late Aircraft Arrival (Minutes)', 'Date UTC /Day',
#        'Average Temperature(Celcius) /Day',
#        'Minimum Temperature(Celcius) /Day',
#        'Maximum Temperature(Celcius) /Day', 'Daily Precipitation(mm) /Day',
#        'Maximum Snowfall(mm) /Day', 'Wind Direction(Degrees) /Day',
#        'Wind Speed(km/h) /Day', 'Peak Wind Gust(km/h) /Day',
#        'Atmospheric Pressure(hPa) /Day', 'Sunshine Duration(m) /Day'],
#       dtype='object')

# %%
dataset['Carrier Code'].unique()
# Out:
# array(['UA'], dtype=object)

# %%
dataset.sort_values(['Date (MM/DD/YYYY)'],ascending=True)
# Out:
#     Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number Origin Airport  \
# 733           UA        2017-06-08           1500      N464UA            ORD
# 738           UA        2017-06-09           1500      N819UA            ORD
# 744           UA        2017-06-10            849      N492UA            ORD
# 745           UA        2017-06-10           1500      N806UA            ORD
# 751           UA        2017-06-11           1500      N434UA            ORD
# ..           ...               ...            ...         ...            ...
# 163           UA        2023-01-30           1998      N836UA            ORD
# 164           UA        2023-01-30           2617      N66831            EWR
# 168           UA        2023-01-31            604      N851UA            DEN
# 169           UA        2023-01-31           1998      N808UA            ORD
# 170           UA        2023-01-31           2617      N68807            EWR
#
#     Scheduled Arrival Time Actual Arrival Time  \
# 733                  16:37               17:01
# 738                  16:37               16:31
# 744                  20:41               21:01
# 745                  16:37               16:22
# 751                  16:37               16:26
# ..                     ...                 ...
# 163                  21:17               21:21
# 164                  23:12               23:15
# 168                  14:59               14:47
# 169                  21:17               20:52
# 170                  23:12               22:59
#
#      Scheduled Elapsed Time (Minutes)  Actual Elapsed Time (Minutes)  \
# 733                               110                            144
# 738                               110                            107
# 744                               111                            117
# 745                               110                            100
# 751                               110                            101
# ..                                ...                            ...
# 163                               113                            103
# 164                                74                             74
# 168                               193                            175
# 169                               113                             97
# 170                                74                             66
#
#      Arrival Delay (Minutes)  ... Average Temperature(Celcius) /Day  \
# 733                       24  ...                              20.6
# 738                       -6  ...                              23.5
# 744                       20  ...                              24.2
# 745                      -15  ...                              24.2
# 751                      -11  ...                              27.7
# ..                       ...  ...                               ...
# 163                        4  ...                              -9.5
# 164                        3  ...                               8.4
# 168                      -12  ...                             -14.9
# 169                      -25  ...                             -14.3
# 170                      -13  ...                               5.6
#
#      Minimum Temperature(Celcius) /Day  Maximum Temperature(Celcius) /Day  \
# 733                               11.7                               28.3
# 738                               18.3                               30.6
# 744                               17.8                               32.2
# 745                               17.8                               32.2
# 751                               22.8                               33.9
# ..                                 ...                                ...
# 163                              -14.9                               -7.7
# 164                                3.9                               13.9
# 168                              -21.6                               -4.9
# 169                              -18.2                              -11.0
# 170                                0.0                                9.4
#
#      Daily Precipitation(mm) /Day  Maximum Snowfall(mm) /Day  \
# 733                           1.5                        0.0
# 738                           0.0                        0.0
# 744                           0.0                        0.0
# 745                           0.0                        0.0
# 751                           0.0                        0.0
# ..                            ...                        ...
# 163                           0.5                       80.0
# 164                           0.0                        0.0
# 168                           0.3                      100.0
# 169                           0.0                       80.0
# 170                           1.5                        0.0
#
#      Wind Direction(Degrees) /Day  Wind Speed(km/h) /Day  \
# 733                           NaN                    6.8
# 738                         250.0                   14.4
# 744                         203.0                   22.7
# 745                         203.0                   22.7
# 751                         199.0                   24.1
# ..                            ...                    ...
# 163                         313.0                   15.5
# 164                         220.0                    9.4
# 168                         178.0                   13.3
# 169                         269.0                    9.7
# 170                         348.0                   16.9
#
#     Peak Wind Gust(km/h) /Day  Atmospheric Pressure(hPa) /Day  \
# 733                       NaN                          1014.4
# 738                       NaN                          1008.4
# 744                       NaN                          1009.3
# 745                       NaN                          1009.3
# 751                       NaN                          1011.8
# ..                        ...                             ...
# 163                       NaN                          1029.7
# 164                       NaN                          1020.2
# 168                       NaN                          1026.1
# 169                       NaN                          1030.7
# 170                       NaN                          1021.9
#
#      Sunshine Duration(m) /Day
# 733                        NaN
# 738                        NaN
# 744                        NaN
# 745                        NaN
# 751                        NaN
# ..                         ...
# 163                        NaN
# 164                        NaN
# 168                        NaN
# 169                        NaN
# 170                        NaN
#
# [2149 rows x 28 columns]

# %%
def delay_status(x):
    if x < -10:
        return 'Early'
    elif x >= -10 and x <= 10:
        return 'On-Time'
    elif x > 10 and x <= 30:
        return 'Late'
    else:
        return 'Severely Late'

# %%
dataset['Status'] = dataset['Arrival Delay (Minutes)'].apply(delay_status)

# %%
dataset['Status'].value_counts()
# Out:
# On-Time          939
# Early            681
# Severely Late    299
# Late             230
# Name: Status, dtype: int64

# %%
dataset['Date (MM/DD/YYYY)'].dt.month
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 2144    12
# 2145    12
# 2146    12
# 2147    12
# 2148    12
# Name: Date (MM/DD/YYYY), Length: 2149, dtype: int64

# %%
test = dataset[dataset['Date (MM/DD/YYYY)'].dt.month.isin([1,2,3,4])]

# %%
test['Status'].value_counts()
# Out:
# On-Time          284
# Early            162
# Severely Late     94
# Late              64
# Name: Status, dtype: int64

# %%
test.sort_values(['Date (MM/DD/YYYY)'],inplace=True)
# Out:
# /Users/anushaprakash/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
test
# Out:
#     Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number Origin Airport  \
# 22            UA        2019-01-07            607      N810UA            ORD
# 27            UA        2019-01-08            607      N4888U            ORD
# 32            UA        2019-01-09            607      N816UA            ORD
# 38            UA        2019-01-10            607      N4888U            ORD
# 45            UA        2019-01-11            607      N897UA            ORD
# ..           ...               ...            ...         ...            ...
# 163           UA        2023-01-30           1998      N836UA            ORD
# 164           UA        2023-01-30           2617      N66831            EWR
# 169           UA        2023-01-31           1998      N808UA            ORD
# 170           UA        2023-01-31           2617      N68807            EWR
# 168           UA        2023-01-31            604      N851UA            DEN
#
#     Scheduled Arrival Time Actual Arrival Time  \
# 22                   20:49               20:18
# 27                   20:49               21:31
# 32                   20:49               20:38
# 38                   20:49               21:14
# 45                   20:49               20:44
# ..                     ...                 ...
# 163                  21:17               21:21
# 164                  23:12               23:15
# 169                  21:17               20:52
# 170                  23:12               22:59
# 168                  14:59               14:47
#
#      Scheduled Elapsed Time (Minutes)  Actual Elapsed Time (Minutes)  \
# 22                                109                             86
# 27                                109                            101
# 32                                109                            106
# 38                                109                            121
# 45                                109                            100
# ..                                ...                            ...
# 163                               113                            103
# 164                                74                             74
# 169                               113                             97
# 170                                74                             66
# 168                               193                            175
#
#      Arrival Delay (Minutes)  ... Minimum Temperature(Celcius) /Day  \
# 22                       -31  ...                               4.4
# 27                        42  ...                              -4.3
# 32                       -11  ...                              -9.3
# 38                        25  ...                              -9.9
# 45                        -5  ...                              -8.2
# ..                       ...  ...                               ...
# 163                        4  ...                             -14.9
# 164                        3  ...                               3.9
# 169                      -25  ...                             -18.2
# 170                      -13  ...                               0.0
# 168                      -12  ...                             -21.6
#
#      Maximum Temperature(Celcius) /Day  Daily Precipitation(mm) /Day  \
# 22                                11.7                          11.2
# 27                                 7.2                           0.0
# 32                                -4.3                           0.0
# 38                                -4.3                           0.0
# 45                                -1.0                           0.0
# ..                                 ...                           ...
# 163                               -7.7                           0.5
# 164                               13.9                           0.0
# 169                              -11.0                           0.0
# 170                                9.4                           1.5
# 168                               -4.9                           0.3
#
#      Maximum Snowfall(mm) /Day  Wind Direction(Degrees) /Day  \
# 22                         0.0                         189.0
# 27                         0.0                         263.0
# 32                         0.0                         308.0
# 38                         0.0                         329.0
# 45                         0.0                         181.0
# ..                         ...                           ...
# 163                       80.0                         313.0
# 164                        0.0                         220.0
# 169                       80.0                         269.0
# 170                        0.0                         348.0
# 168                      100.0                         178.0
#
#      Wind Speed(km/h) /Day  Peak Wind Gust(km/h) /Day  \
# 22                    25.2                        NaN
# 27                    23.4                        NaN
# 32                    22.0                        NaN
# 38                     7.2                        NaN
# 45                     7.9                        NaN
# ..                     ...                        ...
# 163                   15.5                        NaN
# 164                    9.4                        NaN
# 169                    9.7                        NaN
# 170                   16.9                        NaN
# 168                   13.3                        NaN
#
#     Atmospheric Pressure(hPa) /Day  Sunshine Duration(m) /Day         Status
# 22                          1007.0                        NaN          Early
# 27                          1010.2                        NaN  Severely Late
# 32                          1024.6                        NaN          Early
# 38                          1030.2                        NaN           Late
# 45                          1028.2                        NaN        On-Time
# ..                             ...                        ...            ...
# 163                         1029.7                        NaN        On-Time
# 164                         1020.2                        NaN        On-Time
# 169                         1030.7                        NaN          Early
# 170                         1021.9                        NaN          Early
# 168                         1026.1                        NaN          Early
#
# [604 rows x 29 columns]

# %%
dataset.columns
# Out:
# Index(['Carrier Code', 'Date (MM/DD/YYYY)', 'Flight Number', 'Tail Number',
#        'Origin Airport', 'Scheduled Arrival Time', 'Actual Arrival Time',
#        'Scheduled Elapsed Time (Minutes)', 'Actual Elapsed Time (Minutes)',
#        'Arrival Delay (Minutes)', 'Wheels-on Time', 'Taxi-In time (Minutes)',
#        'Delay Carrier (Minutes)', 'Delay Weather (Minutes)',
#        'Delay National Aviation System (Minutes)', 'Delay Security (Minutes)',
#        'Delay Late Aircraft Arrival (Minutes)', 'Date UTC /Day',
#        'Average Temperature(Celcius) /Day',
#        'Minimum Temperature(Celcius) /Day',
#        'Maximum Temperature(Celcius) /Day', 'Daily Precipitation(mm) /Day',
#        'Maximum Snowfall(mm) /Day', 'Wind Direction(Degrees) /Day',
#        'Wind Speed(km/h) /Day', 'Peak Wind Gust(km/h) /Day',
#        'Atmospheric Pressure(hPa) /Day', 'Sunshine Duration(m) /Day',
#        'Status'],
#       dtype='object')

# %%
#pre-processing the data
#one hot encode categorical data

from sklearn.preprocessing import OneHotEncoder

def get_ohe(df, col):
    ohe = OneHotEncoder(handle_unknown='error', sparse=False, dtype='int')
    col_name= ohe.fit(df[[col]])
    temp_df = pd.DataFrame(data=ohe.transform(df[[col]]), columns=ohe.get_feature_names_out())
    df.drop(columns=[col], axis=1, inplace=True)
    df = pd.concat([df.reset_index(drop=True), temp_df], axis=1)
    return df,col_name

# %%
dataset.columns
# Out:
# Index(['Carrier Code', 'Date (MM/DD/YYYY)', 'Flight Number', 'Tail Number',
#        'Origin Airport', 'Scheduled Arrival Time', 'Actual Arrival Time',
#        'Scheduled Elapsed Time (Minutes)', 'Actual Elapsed Time (Minutes)',
#        'Arrival Delay (Minutes)', 'Wheels-on Time', 'Taxi-In time (Minutes)',
#        'Delay Carrier (Minutes)', 'Delay Weather (Minutes)',
#        'Delay National Aviation System (Minutes)', 'Delay Security (Minutes)',
#        'Delay Late Aircraft Arrival (Minutes)', 'Date UTC /Day',
#        'Average Temperature(Celcius) /Day',
#        'Minimum Temperature(Celcius) /Day',
#        'Maximum Temperature(Celcius) /Day', 'Daily Precipitation(mm) /Day',
#        'Maximum Snowfall(mm) /Day', 'Wind Direction(Degrees) /Day',
#        'Wind Speed(km/h) /Day', 'Peak Wind Gust(km/h) /Day',
#        'Atmospheric Pressure(hPa) /Day', 'Sunshine Duration(m) /Day',
#        'Status'],
#       dtype='object')

# %%
#get ohe for flight

data_flight_no,flight_number_ohe = get_ohe(dataset,'Flight Number')
#tail_no_df, tail_number_ohe = get_ohe(data_flight_no,'Tail Number')
origin_air,origin_airport_ohe = get_ohe(data_flight_no,'Origin Airport')

# %%
#drop Carrier code cause its just a single airline

data = origin_air.drop(['Carrier Code','Taxi-In time (Minutes)','Delay Carrier (Minutes)','Delay Weather (Minutes)',
                       'Delay National Aviation System (Minutes)', 'Delay Security (Minutes)',
                        'Delay Late Aircraft Arrival (Minutes)','Date UTC /Day','Wheels-on Time',
                       'Actual Arrival Time','Actual Elapsed Time (Minutes)','Arrival Delay (Minutes)',
                       'Scheduled Elapsed Time (Minutes)','Tail Number','Peak Wind Gust(km/h) /Day',
                       'Sunshine Duration(m) /Day'],axis=1)
data
# Out:
#      Date (MM/DD/YYYY) Scheduled Arrival Time  \
# 0           2022-01-01                  23:10
# 1           2023-01-01                  14:58
# 2           2023-01-01                  23:14
# 3           2023-01-01                  23:57
# 4           2022-01-02                  23:10
# ...                ...                    ...
# 2144        2019-12-31                  18:15
# 2145        2021-12-31                  18:38
# 2146        2022-12-31                  14:58
# 2147        2022-12-31                  21:08
# 2148        2022-12-31                  23:14
#
#       Average Temperature(Celcius) /Day  Minimum Temperature(Celcius) /Day  \
# 0                                  14.4                               13.3
# 1                                  -0.9                               -4.9
# 2                                  11.3                                7.2
# 3                                   4.3                                2.8
# 4                                  14.7                                5.6
# ...                                 ...                                ...
# 2144                                4.6                                3.3
# 2145                               11.9                               10.6
# 2146                               -0.1                               -3.2
# 2147                                0.1                               -3.2
# 2148                               10.3                                7.2
#
#       Maximum Temperature(Celcius) /Day  Daily Precipitation(mm) /Day  \
# 0                                  16.7                          16.5
# 1                                   1.1                           1.3
# 2                                  14.4                           0.0
# 3                                   7.2                           4.1
# 4                                  17.8                           1.8
# ...                                 ...                           ...
# 2144                                7.8                           0.0
# 2145                               16.1                           0.5
# 2146                                9.4                           0.0
# 2147                                3.9                           0.0
# 2148                               12.2                           6.6
#
#       Maximum Snowfall(mm) /Day  Wind Direction(Degrees) /Day  \
# 0                           0.0                         165.0
# 1                         100.0                         111.0
# 2                           0.0                         241.0
# 3                           0.0                         245.0
# 4                           0.0                         324.0
# ...                         ...                           ...
# 2144                        0.0                         294.0
# 2145                        0.0                         201.0
# 2146                      130.0                         189.0
# 2147                        0.0                          23.0
# 2148                        0.0                         354.0
#
#       Wind Speed(km/h) /Day  Atmospheric Pressure(hPa) /Day  ...  \
# 0                       7.6                          1006.7  ...
# 1                      10.4                          1010.5  ...
# 2                      13.0                          1012.6  ...
# 3                       6.1                          1013.7  ...
# 4                      13.0                          1006.6  ...
# ...                     ...                             ...  ...
# 2144                   16.9                          1004.8  ...
# 2145                    7.9                          1012.8  ...
# 2146                   14.0                          1005.0  ...
# 2147                    4.3                          1013.4  ...
# 2148                    2.9                          1015.1  ...
#
#      Flight Number_2419  Flight Number_2488  Flight Number_2615  \
# 0                     0                   0                   0
# 1                     0                   0                   0
# 2                     0                   1                   0
# 3                     0                   0                   0
# 4                     0                   0                   0
# ...                 ...                 ...                 ...
# 2144                  0                   0                   0
# 2145                  0                   0                   0
# 2146                  0                   0                   0
# 2147                  0                   0                   0
# 2148                  0                   1                   0
#
#       Flight Number_2617  Flight Number_2634  Flight Number_2645  \
# 0                      0                   0                   0
# 1                      0                   0                   0
# 2                      0                   0                   0
# 3                      0                   0                   1
# 4                      0                   0                   0
# ...                  ...                 ...                 ...
# 2144                   0                   0                   0
# 2145                   0                   0                   0
# 2146                   0                   0                   0
# 2147                   0                   0                   0
# 2148                   0                   0                   0
#
#       Origin Airport_DEN  Origin Airport_EWR  Origin Airport_IAD  \
# 0                      0                   0                   1
# 1                      1                   0                   0
# 2                      0                   1                   0
# 3                      0                   0                   0
# 4                      0                   0                   1
# ...                  ...                 ...                 ...
# 2144                   0                   1                   0
# 2145                   0                   0                   1
# 2146                   1                   0                   0
# 2147                   0                   0                   0
# 2148                   0                   1                   0
#
#       Origin Airport_ORD
# 0                      0
# 1                      0
# 2                      0
# 3                      1
# 4                      0
# ...                  ...
# 2144                   0
# 2145                   0
# 2146                   0
# 2147                   1
# 2148                   0
#
# [2149 rows x 107 columns]

# %%
data.columns[0:20]
# Out:
# Index(['Date (MM/DD/YYYY)', 'Scheduled Arrival Time',
#        'Average Temperature(Celcius) /Day',
#        'Minimum Temperature(Celcius) /Day',
#        'Maximum Temperature(Celcius) /Day', 'Daily Precipitation(mm) /Day',
#        'Maximum Snowfall(mm) /Day', 'Wind Direction(Degrees) /Day',
#        'Wind Speed(km/h) /Day', 'Atmospheric Pressure(hPa) /Day', 'Status',
#        'Flight Number_212', 'Flight Number_279', 'Flight Number_288',
#        'Flight Number_308', 'Flight Number_316', 'Flight Number_333',
#        'Flight Number_358', 'Flight Number_360', 'Flight Number_376'],
#       dtype='object')

# %%
data= data.fillna(data.median())
# Out:
# <ipython-input-20-2efcee8b0341>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data= data.fillna(data.median())
# <ipython-input-20-2efcee8b0341>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data= data.fillna(data.median())

# %%
# Define custom method to convert date column
def convert_date(date_str):
    date_obj = pd.to_datetime(date_str)  # Convert date string to datetime object
    return date_obj.strftime('%m/%d/%Y')  # Format datetime object into desired format

# Apply custom method to date column using apply()
data['Date'] = data['Date (MM/DD/YYYY)'].apply(convert_date)
data.drop(['Date (MM/DD/YYYY)'],axis=1,inplace=True)

# %%
# Define custom method to convert date column
def convert_time(date_str):
    date_obj = pd.to_datetime(date_str)  # Convert date string to datetime object
    return date_obj.strftime("%I:%M %p")

# %%
data['Arrival Time']= data['Scheduled Arrival Time'].apply(convert_time)

# %%
data.drop(['Scheduled Arrival Time'],axis=1,inplace=True)

# %%
data['Arrival Time'] = pd.to_datetime(data['Arrival Time'])
data['Hour'] = data['Arrival Time'].dt.hour
data['Minute'] = data['Arrival Time'].dt.minute

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['Day'] = data['Date'].dt.strftime('%A')

# %%
data.isna().sum()
# Out:
# Average Temperature(Celcius) /Day    0
# Minimum Temperature(Celcius) /Day    0
# Maximum Temperature(Celcius) /Day    0
# Daily Precipitation(mm) /Day         0
# Maximum Snowfall(mm) /Day            0
#                                     ..
# Date                                 0
# Arrival Time                         0
# Hour                                 0
# Minute                               0
# Day                                  0
# Length: 110, dtype: int64

# %%
data['year'] = data.Date.dt.year
data['month'] = data.Date.dt.month
data['day'] = data.Date.dt.day
data.drop(['Date'],axis=1,inplace=True)

# %%
data, week_ohe = get_ohe(data,'Day')

# %%
status,status_ohe= get_ohe(data,'Status')

# %%
status.columns[115:]
# Out:
# Index(['Day_Tuesday', 'Day_Wednesday', 'Status_Early', 'Status_Late',
#        'Status_On-Time', 'Status_Severely Late'],
#       dtype='object')

# %%
status['day']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        2
#         ..
# 2144    31
# 2145    31
# 2146    31
# 2147    31
# 2148    31
# Name: day, Length: 2149, dtype: int64

# %%
status.to_csv("Pre-processed_data_20thapril.csv",index=False)

# %%
Y = status[['Status_Early', 'Status_Late', 'Status_On-Time',
       'Status_Severely Late']]
Y
# Out:
#       Status_Early  Status_Late  Status_On-Time  Status_Severely Late
# 0                0            0               0                     1
# 1                0            0               1                     0
# 2                0            0               1                     0
# 3                0            0               1                     0
# 4                0            1               0                     0
# ...            ...          ...             ...                   ...
# 2144             0            0               1                     0
# 2145             0            0               1                     0
# 2146             1            0               0                     0
# 2147             1            0               0                     0
# 2148             0            0               0                     1
#
# [2149 rows x 4 columns]

# %%
X = status.loc[:,~status.columns.isin(['Status_Early', 'Status_Late', 'Status_On-Time',
       'Status_Severely Late','Arrival Time'])]

# %%
X.columns[100:]
# Out:
# Index(['Origin Airport_DEN', 'Origin Airport_EWR', 'Origin Airport_IAD',
#        'Origin Airport_ORD', 'Hour', 'Minute', 'year', 'month', 'day',
#        'Day_Friday', 'Day_Monday', 'Day_Saturday', 'Day_Sunday',
#        'Day_Thursday', 'Day_Tuesday', 'Day_Wednesday'],
#       dtype='object')

# %%
#split our dataset
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.20, random_state=42)

# %%
#scale our data
sc = StandardScaler().fit(X_train)
X_train = pd.DataFrame(sc.transform(X_train),index=X_train.index,columns = X_train.columns)
X_train
# Out:
#       Average Temperature(Celcius) /Day  Minimum Temperature(Celcius) /Day  \
# 1433                           0.591358                           0.637872
# 630                           -0.101544                          -0.161510
# 78                            -1.098185                          -1.163146
# 366                           -0.481217                          -0.903106
# 1996                          -0.500200                          -0.643066
# ...                                 ...                                ...
# 1638                           0.714752                           0.637872
# 1095                           1.350703                           1.340944
# 1130                           0.857129                           0.801601
# 1294                           1.018490                           1.119428
# 860                            0.847637                           0.801601
#
#       Maximum Temperature(Celcius) /Day  Daily Precipitation(mm) /Day  \
# 1433                           0.565808                     -0.368856
# 630                           -0.072641                     -0.368856
# 78                            -0.915039                     -0.368856
# 366                            0.219981                     -0.368856
# 1996                          -0.374131                     -0.245480
# ...                                 ...                           ...
# 1638                           0.858431                     -0.368856
# 1095                           1.301798                      0.571892
# 1130                           0.858431                     -0.368856
# 1294                           1.062380                     -0.368856
# 860                            1.009176                     -0.368856
#
#       Maximum Snowfall(mm) /Day  Wind Direction(Degrees) /Day  \
# 1433                  -0.233644                      1.511669
# 630                   -0.233644                     -1.538013
# 78                    -0.233644                     -0.098163
# 366                   -0.233644                      0.471778
# 1996                  -0.233644                     -0.118161
# ...                         ...                           ...
# 1638                  -0.233644                     -0.218151
# 1095                  -0.233644                      0.651759
# 1130                  -0.233644                     -1.428025
# 1294                  -0.233644                      0.111815
# 860                   -0.233644                      0.281797
#
#       Wind Speed(km/h) /Day  Atmospheric Pressure(hPa) /Day  \
# 1433              -1.014789                       -0.130630
# 630                0.321852                       -0.217965
# 78                -0.504755                       -2.037447
# 366                0.638425                        0.087708
# 1996               1.764018                       -1.658995
# ...                     ...                             ...
# 1638               0.954998                        0.640830
# 1095              -1.137901                       -0.581862
# 1130              -1.085139                        0.640830
# 1294              -0.944440                       -0.217965
# 860               -0.381643                        0.800945
#
#       Flight Number_212  Flight Number_279  ...      year     month       day  \
# 1433          -0.041812          -0.041812  ...  0.173627  0.662570 -0.787255
# 630           -0.041812          -0.041812  ...  0.761155 -0.560472 -1.015601
# 78            -0.041812          -0.041812  ...  1.348683 -1.783515  0.011955
# 366           -0.041812          -0.041812  ...  0.761155 -1.171993 -0.102218
# 1996          -0.041812          -0.041812  ...  0.761155  1.274091  1.496203
# ...                 ...                ...  ...       ...       ...       ...
# 1638          -0.041812          -0.041812  ... -2.176486  0.968331 -1.586465
# 1095          -0.041812          -0.041812  ...  0.761155  0.051049  1.382030
# 1130          -0.041812          -0.041812  ... -1.001430  0.356810 -1.586465
# 1294          -0.041812          -0.041812  ...  0.173627  0.356810  0.811166
# 860           -0.041812          -0.041812  ...  0.761155 -0.254712  1.382030
#
#       Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# 1433   -0.425008   -0.405751     -0.376077   -0.437342      2.452820
# 630    -0.425008   -0.405751      2.659027   -0.437342     -0.407694
# 78     -0.425008    2.464564     -0.376077   -0.437342     -0.407694
# 366    -0.425008   -0.405751     -0.376077   -0.437342     -0.407694
# 1996   -0.425008   -0.405751     -0.376077   -0.437342     -0.407694
# ...          ...         ...           ...         ...           ...
# 1638   -0.425008    2.464564     -0.376077   -0.437342     -0.407694
# 1095   -0.425008   -0.405751     -0.376077   -0.437342      2.452820
# 1130    2.352896   -0.405751     -0.376077   -0.437342     -0.407694
# 1294   -0.425008    2.464564     -0.376077   -0.437342     -0.407694
# 860    -0.425008   -0.405751     -0.376077   -0.437342     -0.407694
#
#       Day_Tuesday  Day_Wednesday
# 1433    -0.402830      -0.401854
# 630     -0.402830      -0.401854
# 78      -0.402830      -0.401854
# 366      2.482438      -0.401854
# 1996     2.482438      -0.401854
# ...           ...            ...
# 1638    -0.402830      -0.401854
# 1095    -0.402830      -0.401854
# 1130    -0.402830      -0.401854
# 1294    -0.402830      -0.401854
# 860      2.482438      -0.401854
#
# [1719 rows x 116 columns]

# %%
#get sample weights
from sklearn.utils.class_weight import compute_sample_weight

sample_weights = compute_sample_weight("balanced", y_train)

# %%
sample_weights
# Out:
# array([0.43756477, 0.2809572 , 0.2809572 , ..., 0.43756477, 0.43756477,
#        0.2809572 ])

# %%
X_train
# Out:
#       Average Temperature(Celcius) /Day  Minimum Temperature(Celcius) /Day  \
# 1433                           0.591358                           0.637872
# 630                           -0.101544                          -0.161510
# 78                            -1.098185                          -1.163146
# 366                           -0.481217                          -0.903106
# 1996                          -0.500200                          -0.643066
# ...                                 ...                                ...
# 1638                           0.714752                           0.637872
# 1095                           1.350703                           1.340944
# 1130                           0.857129                           0.801601
# 1294                           1.018490                           1.119428
# 860                            0.847637                           0.801601
#
#       Maximum Temperature(Celcius) /Day  Daily Precipitation(mm) /Day  \
# 1433                           0.565808                     -0.368856
# 630                           -0.072641                     -0.368856
# 78                            -0.915039                     -0.368856
# 366                            0.219981                     -0.368856
# 1996                          -0.374131                     -0.245480
# ...                                 ...                           ...
# 1638                           0.858431                     -0.368856
# 1095                           1.301798                      0.571892
# 1130                           0.858431                     -0.368856
# 1294                           1.062380                     -0.368856
# 860                            1.009176                     -0.368856
#
#       Maximum Snowfall(mm) /Day  Wind Direction(Degrees) /Day  \
# 1433                  -0.233644                      1.511669
# 630                   -0.233644                     -1.538013
# 78                    -0.233644                     -0.098163
# 366                   -0.233644                      0.471778
# 1996                  -0.233644                     -0.118161
# ...                         ...                           ...
# 1638                  -0.233644                     -0.218151
# 1095                  -0.233644                      0.651759
# 1130                  -0.233644                     -1.428025
# 1294                  -0.233644                      0.111815
# 860                   -0.233644                      0.281797
#
#       Wind Speed(km/h) /Day  Atmospheric Pressure(hPa) /Day  \
# 1433              -1.014789                       -0.130630
# 630                0.321852                       -0.217965
# 78                -0.504755                       -2.037447
# 366                0.638425                        0.087708
# 1996               1.764018                       -1.658995
# ...                     ...                             ...
# 1638               0.954998                        0.640830
# 1095              -1.137901                       -0.581862
# 1130              -1.085139                        0.640830
# 1294              -0.944440                       -0.217965
# 860               -0.381643                        0.800945
#
#       Flight Number_212  Flight Number_279  ...      year     month       day  \
# 1433          -0.041812          -0.041812  ...  0.173627  0.662570 -0.787255
# 630           -0.041812          -0.041812  ...  0.761155 -0.560472 -1.015601
# 78            -0.041812          -0.041812  ...  1.348683 -1.783515  0.011955
# 366           -0.041812          -0.041812  ...  0.761155 -1.171993 -0.102218
# 1996          -0.041812          -0.041812  ...  0.761155  1.274091  1.496203
# ...                 ...                ...  ...       ...       ...       ...
# 1638          -0.041812          -0.041812  ... -2.176486  0.968331 -1.586465
# 1095          -0.041812          -0.041812  ...  0.761155  0.051049  1.382030
# 1130          -0.041812          -0.041812  ... -1.001430  0.356810 -1.586465
# 1294          -0.041812          -0.041812  ...  0.173627  0.356810  0.811166
# 860           -0.041812          -0.041812  ...  0.761155 -0.254712  1.382030
#
#       Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# 1433   -0.425008   -0.405751     -0.376077   -0.437342      2.452820
# 630    -0.425008   -0.405751      2.659027   -0.437342     -0.407694
# 78     -0.425008    2.464564     -0.376077   -0.437342     -0.407694
# 366    -0.425008   -0.405751     -0.376077   -0.437342     -0.407694
# 1996   -0.425008   -0.405751     -0.376077   -0.437342     -0.407694
# ...          ...         ...           ...         ...           ...
# 1638   -0.425008    2.464564     -0.376077   -0.437342     -0.407694
# 1095   -0.425008   -0.405751     -0.376077   -0.437342      2.452820
# 1130    2.352896   -0.405751     -0.376077   -0.437342     -0.407694
# 1294   -0.425008    2.464564     -0.376077   -0.437342     -0.407694
# 860    -0.425008   -0.405751     -0.376077   -0.437342     -0.407694
#
#       Day_Tuesday  Day_Wednesday
# 1433    -0.402830      -0.401854
# 630     -0.402830      -0.401854
# 78      -0.402830      -0.401854
# 366      2.482438      -0.401854
# 1996     2.482438      -0.401854
# ...           ...            ...
# 1638    -0.402830      -0.401854
# 1095    -0.402830      -0.401854
# 1130    -0.402830      -0.401854
# 1294    -0.402830      -0.401854
# 860      2.482438      -0.401854
#
# [1719 rows x 116 columns]

# %%
# !pip install xgboost
from xgboost import XGBClassifier
from sklearn.ensemble import *

model = XGBClassifier(n_estimators=100, learning_rate=1.0,max_depth=4, random_state=0)
model = model.fit(X_train,y_train,sample_weight=sample_weights)

model.score(X_train,y_train)
# Out:
# Requirement already satisfied: xgboost in /Users/anushaprakash/opt/anaconda3/lib/python3.8/site-packages (1.7.5)
# Requirement already satisfied: scipy in /Users/anushaprakash/opt/anaconda3/lib/python3.8/site-packages (from xgboost) (1.6.2)
# Requirement already satisfied: numpy in /Users/anushaprakash/opt/anaconda3/lib/python3.8/site-packages (from xgboost) (1.21.6)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-65b2f2463797> in <module>
#       4
#       5 model = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,max_depth=4, random_state=0)
# ----> 6 model = model.fit(X_train,y_train,sample_weight=sample_weights)
#       7
#       8 model.score(X_train,y_train)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py in fit(self, X, y, sample_weight, monitor)
#     568         sample_weight = _check_sample_weight(sample_weight, X)
#     569
# --> 570         y = column_or_1d(y, warn=True)
#     571
#     572         if is_classifier(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in column_or_1d(y, warn)
#    1154         return np.ravel(y)
#    1155
# -> 1156     raise ValueError(
#    1157         "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1158     )
#
# ValueError: y should be a 1d array, got an array of shape (1719, 4) instead.

# %%
y_train

# %%
print(classification_report(model.predict(X_train),y_train,target_names = list(y_train.columns)))

# %%
model.score(sc.transform(X_test),y_test)

# %%
print(classification_report(model.predict(sc.transform(X_test)),y_test,target_names = list(y_train.columns)))
